# %% [markdown]
# ### TO DO
# 1. data preprocessing
# - notes we got: For example, the vote count and popularity score variables may not be good features to use as they are more likely to be response variables. A good rule of thumb is: if there is a new movie that has not been released yet, what features will we have and which will be not have?
# 2. train linear regression
# - use budget & time of year to keep it simple
# - flag
# 3. train polynomial
# - same deal as above
# 4. train RF
# - add categorical vars
# 5. train adaboost
# - same deal

# %% [markdown]
# ### Data Cleaning
# 1. do we keep 2020 in there since that year is messed up
# 2. how do we standardize/ can we keep reviews in there??
# 3. are we doing profit?

# %%
SARA_FILEPATH = '/Users/sarakent/Desktop/ML 1/TMDB_movie_dataset_v11.csv'   #too large to add to git, adding file path ehre

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv(SARA_FILEPATH)
df.head(2)
# Out:
#        id         title  vote_average  vote_count    status release_date  \
# 0   27205     Inception         8.364       34495  Released   2010-07-15
# 1  157336  Interstellar         8.417       32571  Released   2014-11-05
#
#      revenue  runtime  adult                     backdrop_path  ...  \
# 0  825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1  701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
#
#    original_language original_title  \
# 0                 en      Inception
# 1                 en   Interstellar
#
#                                             overview popularity  \
# 0  Cobb, a skilled thief who commits corporate es...     83.952
# 1  The adventures of a group of explorers who mak...    140.241
#
#                         poster_path  \
# 0  /oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg
# 1  /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg
#
#                                              tagline  \
# 0               Your mind is the scene of the crime.
# 1  Mankind was born on Earth. It was never meant ...
#
#                                genres  \
# 0  Action, Science Fiction, Adventure
# 1   Adventure, Drama, Science Fiction
#
#                                 production_companies  \
# 0  Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1  Legendary Pictures, Syncopy, Lynda Obst Produc...
#
#                        production_countries  \
# 0  United Kingdom, United States of America
# 1  United Kingdom, United States of America
#
#                      spoken_languages
# 0  English, French, Japanese, Swahili
# 1                             English
#
# [2 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['id', 'title', 'vote_average', 'vote_count', 'status', 'release_date',
#        'revenue', 'runtime', 'adult', 'backdrop_path', 'budget', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'tagline', 'genres',
#        'production_companies', 'production_countries', 'spoken_languages'],
#       dtype='object')

# %%
# keeping columns we are interested in
col_lst = ['id', 'title', 'vote_average', 'vote_count', 'status', 'release_date', 'revenue',
          'runtime', 'adult', 'budget', 'popularity', 'genres', 'production_companies',
          'spoken_languages']
df = df[col_lst]
df['release_date'] = pd.to_datetime(df.release_date)
df = df[(df['status'] == 'Released') & 
        (df['budget'] > 10000) & 
        (df['release_date'].notna()) & 
        (df['runtime'] != 0) & 
        (df['release_date'] > '1960-01-01') & 
        ((df['release_date'] < '2020-01-01') | 
        (df['release_date'] > '2020-12-31'))]

# %%
df['profit'] = df.revenue - df.budget

# %%
df.profit.mean(), df.profit.max(), df.profit.min()
# Out:
# (17935418.752220534, 2686706026, -888000000)

# %%
plt.figure(figsize=(20, 10))
plt.scatter(df.release_date, df.profit)
plt.show()

# %% [markdown]
# Production Companies
# 1. Castle Rock Entertainment
# 2. Paramount Pictures
# 3. Warner Bros.
# 4. Universal Pictures
# 5. New Line Cinema
# 6. Miramax
# 7. Produzioni Europee Associate (PEA)
# 8. Lucasfilm
# 9. Toho Company
# 10. Dreamworks Pictures
# 11. Studio Ghibli
# 12. CJ Entertainment
# 13. Walt Disney Pictures
# 14. PolyGram Filmed Entertainment
# 15. Touchstone Pictures
# 16. Charles Chaplin Productions
# 17. Shochiku
# 18. Alfred J. Hitchcock Productions
# 19. Pixar Animation Studios
# 20. Marvel Studios
# 21. Twentieth Century Fox
# 22. Stanley Kubrick Productions
# 23. The Ladd Company
# 24. Metro-Goldwyn-Mayer (MGM)
# 25. Kurosawa Production Co.
# 26. Horizon Pictures (II)
# 27. Zanuck/Brown Productions
# 28. Columbia Pictures
# 29. New Regency Productions
# 30. Aamir Khan Productions
# 31. Malpaso Productions
# 32. Paramount Vantage
# 33. Python (Monty) Pictures
# 34. Chartoff-Winkler Productions
# 35. Selznick International Pictures
# 36. Summit Entertainment
# 37. Buster Keaton Productions
# 38. Svensk Filmindustri (SF)
